# %% [markdown]
# # Clothing Dataset - Statistics Project
# Clothing Dataset - Statistics Project
#
# This project explores a dataset containing information about various clothing items. The dataset includes the following features:
#
# -Brand – The name of the clothing brand
#
# -Category – Type of clothing (e.g., shirt, pants, dress)
#
# -Color – The main color of the item
#
# -Size – Available size (e.g., S, M, L, XL)
#
# -Material – The fabric or material used (e.g., cotton, polyester)
#
# -Price – Price of the clothing item in USD
#
# We use statistical techniques to analyze trends, relationships, and patterns within the dataset. The goal is to understand how different factors such as brand, size, and material relate to pricing and categorization.

# %%
# # Load the necessary packages
import pandas as pd
import numpy as np

# %%
mydata = pd.read_csv('/content/clothes.csv')

# %%
mydata.tail(5)
# Out:
#             Brand Category   Color Size   Material  Price
# 995          Puma    Jeans   Black    L  Polyester    176
# 996          Puma   Jacket     Red  XXL       Silk    110
# 997        Reebok  Sweater    Blue   XS      Denim    127
# 998  Under Armour  Sweater   Black  XXL      Denim     69
# 999   New Balance   Jacket  Yellow   XS       Wool    174

# %%
# Load the Cardio Dataset
mydata = pd.read_csv('/content/clothes.csv')

# %%
# mydata.head()
# mydata.columns
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Brand     1000 non-null   object
#  1   Category  1000 non-null   object
#  2   Color     1000 non-null   object
#  3   Size      1000 non-null   object
#  4   Material  1000 non-null   object
#  5   Price     1000 non-null   int64
# dtypes: int64(1), object(5)
# memory usage: 47.0+ KB

# %%
mydata.describe()
# Out:
#              Price
# count  1000.000000
# mean    106.289000
# std      53.695444
# min      10.000000
# 25%      59.750000
# 50%     108.000000
# 75%     150.000000
# max     199.000000

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

mydata.hist(figsize=(30,40))
plt.show()

# %%
import seaborn as sns

sns.boxplot(x="Brand", y="Category", data=mydata)
# Out:
# <Axes: xlabel='Brand', ylabel='Category'>

# %%
pd.crosstab(mydata['Brand'],mydata['Color'] )
# Out:
# Color         Black  Blue  Green  Red  White  Yellow
# Brand
# Adidas           36    27     21   28     33      21
# New Balance      30    22     31   25     26      30
# Nike             28    19     30   23     37      28
# Puma             24    35     23   27     25      34
# Reebok           17    30     26   30     26      29
# Under Armour     28    30     31   35     24      31

# %%
pd.crosstab(mydata['Category'],mydata['Color'] )
# Out:
# Color     Black  Blue  Green  Red  White  Yellow
# Category
# Dress        21    26     27   32     30      30
# Jacket       38    34     30   27     35      27
# Jeans        30    31     23   25     26      32
# Shoes        29    29     29   26     27      32
# Sweater      21    20     26   33     32      28
# T-shirt      24    23     27   25     21      24

# %%
sns.countplot(x="Brand", hue="Price", data=mydata)
# Out:
# <Axes: xlabel='Brand', ylabel='count'>

# %%
pd.pivot_table(mydata, index=['Brand', 'Category'],
                     columns=[ 'Color'], aggfunc=len)
# Out:
#                       Material                              Price             \
# Color                    Black Blue Green  Red White Yellow Black Blue Green
# Brand        Category
# Adidas       Dress         2.0  4.0   3.0  7.0   9.0    5.0   2.0  4.0   3.0
#              Jacket        9.0  9.0   2.0  3.0   2.0    3.0   9.0  9.0   2.0
#              Jeans         9.0  5.0   3.0  5.0   9.0    8.0   9.0  5.0   3.0
#              Shoes         6.0  3.0   5.0  6.0   3.0    2.0   6.0  3.0   5.0
#              Sweater       3.0  3.0   5.0  2.0   6.0    1.0   3.0  3.0   5.0
#              T-shirt       7.0  3.0   3.0  5.0   4.0    2.0   7.0  3.0   3.0
# New Balance  Dress         3.0  5.0   5.0  3.0   6.0    5.0   3.0  5.0   5.0
#              Jacket        7.0  4.0   5.0  7.0   4.0    7.0   7.0  4.0   5.0
#              Jeans         9.0  3.0   2.0  1.0   5.0    4.0   9.0  3.0   2.0
#              Shoes         4.0  6.0   8.0  4.0   5.0    4.0   4.0  6.0   8.0
# ...

# %%
pd.pivot_table(mydata,'Price', index=['Brand', 'Category'],
                     columns=[ 'Color'])
# Out:
# Color                       Black        Blue       Green         Red  \
# Brand        Category
# Adidas       Dress     116.500000   93.250000  114.333333  101.285714
#              Jacket     90.333333  106.222222  100.000000  136.333333
#              Jeans     103.777778  107.200000   53.333333   59.200000
#              Shoes     117.166667  144.000000  126.200000   91.833333
#              Sweater    69.333333   72.000000  100.000000   83.500000
#              T-shirt   157.428571   88.666667  135.666667   98.000000
# New Balance  Dress     111.000000  164.800000  105.600000  130.666667
#              Jacket    130.571429  109.250000   89.200000  102.285714
#              Jeans     101.333333  117.666667  137.000000   98.000000
#              Shoes      89.000000  108.000000  100.875000  122.250000
#              Sweater   106.000000         NaN  150.833333  121.000000
#              T-shirt    71.250000  119.000000  125.800000  136.500000
# ...

# %%
mydata['Price'].std()
# Out:
# 53.69544375158555

# %%
mydata['Price'].mean()
# Out:
# np.float64(106.289)

# %%
sns.displot(mydata['Price'])

# %%
mydata.hist(by='Category',column = 'Material')
# Out:
# array([[<Axes: title={'center': 'Dress'}>,
#         <Axes: title={'center': 'Jacket'}>],
#        [<Axes: title={'center': 'Jeans'}>,
#         <Axes: title={'center': 'Shoes'}>],
#        [<Axes: title={'center': 'Sweater'}>,
#         <Axes: title={'center': 'T-shirt'}>]], dtype=object)

# %%
mydata.hist(by='Category',column = 'Color')
# Out:
# array([[<Axes: title={'center': 'Dress'}>,
#         <Axes: title={'center': 'Jacket'}>],
#        [<Axes: title={'center': 'Jeans'}>,
#         <Axes: title={'center': 'Shoes'}>],
#        [<Axes: title={'center': 'Sweater'}>,
#         <Axes: title={'center': 'T-shirt'}>]], dtype=object)

# %%
mydata.hist(by='Category',column = 'Size')
# Out:
# array([[<Axes: title={'center': 'Dress'}>,
#         <Axes: title={'center': 'Jacket'}>],
#        [<Axes: title={'center': 'Jeans'}>,
#         <Axes: title={'center': 'Shoes'}>],
#        [<Axes: title={'center': 'Sweater'}>,
#         <Axes: title={'center': 'T-shirt'}>]], dtype=object)

# %%
mydata.hist(by='Brand',column = 'Size', figsize=(20,30))
# Out:
# array([[<Axes: title={'center': 'Adidas'}>,
#         <Axes: title={'center': 'New Balance'}>],
#        [<Axes: title={'center': 'Nike'}>,
#         <Axes: title={'center': 'Puma'}>],
#        [<Axes: title={'center': 'Reebok'}>,
#         <Axes: title={'center': 'Under Armour'}>]], dtype=object)

# %%
sns.pairplot(mydata)

# %% [markdown]
# <style>
#   ul {
#     background-color: black;
#   }
#
# <div>
# <span style="color: pink;">
# <h2> Project: concider specification of your dataset </h2>
#     <h3>
#     <ul>
#   <li>Apply all above codes</li>
#   <li>Allways be creative to find interested information</li>
#   <li> Arrange and clean up your GitHub</li>
#     </ul>
#     </h3>
# </div>
#     </style>
